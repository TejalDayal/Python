# %%
import pandas as pd
mydataset=pd.read_csv('Reliance.csv')
x=mydataset.iloc[:,:].value
for row in x:
    if row[4]>25:
        row[5]=('increase')
    elif row[4]<25:
        row[5]=('decrease')
    else:
        row[5]=('no change')
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-cb4ec9e516f7> in <module>()
# ----> 1 import pandas as pd
#       2 mydataset=pd.read_csv('Reliance.csv')
#       3 x=mydataset.iloc[:,:].value
#       4 for row in x:
#       5     if row[4]>25:
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/58/9a/f571a032f5f2bf5b8a5d63ce079428c5423299853ed2d8d96626f441801d/pandas-0.23.3-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl
# ...
#     46% |██████████████▉                 | 11.3MB 826kB/s eta 0:00:16Exception:
# Traceback (most recent call last):
#   File "/Library/Python/2.7/site-packages/pip-10.0.1-py2.7.egg/pip/_internal/basecommand.py", line 228, in main
#     status = self.run(options, args)
#   File "/Library/Python/2.7/site-packages/pip-10.0.1-py2.7.egg/pip/_internal/commands/install.py", line 291, in run
#     resolver.resolve(requirement_set)
#   File "/Library/Python/2.7/site-packages/pip-10.0.1-py2.7.egg/pip/_internal/resolve.py", line 103, in resolve
#     self._resolve_one(requirement_set, req)
#   File "/Library/Python/2.7/site-packages/pip-10.0.1-py2.7.egg/pip/_internal/resolve.py", line 257, in _resolve_one
# ...

# %%
# !pip3 install pandas
# Out:
# ...
#   Cache entry deserialization failed, entry ignored
# ...
#     100% |████████████████████████████████| 14.0MB 1.0MB/s ta 0:00:01
# ...
#   Cache entry deserialization failed, entry ignored
# ...
#     100% |████████████████████████████████| 24.5MB 593kB/s ta 0:00:01   32% |██████████▍                     | 7.9MB 936kB/s eta 0:00:18
# ...
#     100% |████████████████████████████████| 512kB 102kB/s ta 0:00:01
# ...

# %%
import pandas as pd
mydataset=pd.read_csv('Reliance.csv')
x=mydataset.iloc[:,:].value
for row in x:
    if row[4]>25:
        row[5]=('increase')
    elif row[4]<25:
        row[5]=('decrease')
    else:
        row[5]=('no change')
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-cb4ec9e516f7> in <module>()
#       1 import pandas as pd
#       2 mydataset=pd.read_csv('Reliance.csv')
# ----> 3 x=mydataset.iloc[:,:].value
#       4 for row in x:
#       5     if row[4]>25:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value'

# %%
import pandas as pd
mydataset=pd.read_csv('Reliance.csv')
x=mydataset.iloc[:,:].values
df=pd.DataFrame(x)
for row in x:
    if row[5]>25:
        row[6]=('increase')
    elif row[5]<25:
        row[6]=('decrease')
    else:
        row[6]=('no change')
df
# Out:
#        0                 1      2    3    4    5          6
# 0      1            Butter     40   40   50   13   decrease
# 1      4  Chocolate Spread    320  350   50   19   decrease
# 2      5        Garlic Dip    200  240   50   47   increase
# 3      5        Garlic Dip    250  260   50  NaN  no change
# 4      6    Condensed Milk     55   60   50   33   increase
# 5      6             Cream     52   50   50   19   decrease
# 6      7    Dairy Whitener     92   80   50   21   decrease
# 7     11            Yogurt     75   70   50    2   decrease
# 8     11            Yogurt     40   35   50   43   increase
# 9     11            Yogurt     28   30   50   14   decrease
# 10    12              Cake     20   25   50  NaN  no change
# 11    12              Cake     15   15   50   17   decrease
# 12    13              Rusk     46   50   50   18   decrease
# 13    14           Muffins     40   35   50    8   decrease
# 14    16             Bread     33   30   50    8   decrease
# ...

# %%
import pandas as pd
mydataset=pd.read_csv('Reliance.csv')
x=mydataset.iloc[:,:].values
df=pd.DataFrame(x)
df.datatypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-f691c3428b58> in <module>()
#       3 x=mydataset.iloc[:,:].values
#       4 df=pd.DataFrame(x)
# ----> 5 df.datatypes
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'datatypes'
